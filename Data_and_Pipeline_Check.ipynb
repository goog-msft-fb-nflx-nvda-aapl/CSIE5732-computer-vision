# %% [markdown]
# # <font style="color:blue">Table of Content</font>
#
# - [Step 1: Understand Your Problem](#step1)
# - [Step 2A: Get the Data](#step2a)
# - [Step 2B: Explore the Data](#step2b)
# - [Step 2C: Create Sample Data](#step2c)
# - [Step 3. Data Preparation](#step3)
# - [Step 4: Train a Simple Model](#step4)
# - [Step 5: Sample Prediction](#predictions)
# - [Step 6. Display Mistakes](#display)

# %% [markdown]
# # <font style="color:blue">Project 1 - Part 1: Data Understanding & Pipeline Check</font>
#
# Here, we will slightly modify the steps  we had used to train Neural Networks:
#
#
# - Step 1 - Understand your problem
# - Step 2A - Get the data
# - Step 2B - Explore & Understand your data
# - Step 2C - Create a sample data from the dataset
# - Step 3 - Data Preparation
# - Step 4 - Train a simple model on sample data, and check the pipeline before training the full network
# - Step 5 - Train on full Data
# - Step 6 - Improve your model
#
#
# In this notebook we will detail the steps 1 to 4, and do some coding along the way! You will implement Steps 5 & 6 in the next notebook.
#
# This notebook contains  30 points. <font style="color:red">The sections in red are the ones that carry marks.</font>

# %% [markdown]
# # <font style="color:blue">Step 1: Understand Your Problem </font><a name="step1"></a>
#
# As you already know, Image Classification helps classify an image based on its visual content. So, the model is supposed to look at the given image and predict which object is present in it. Obviously, the number of objects which it can predict depends on how many you trained it on.
#
#
# In our problem, we want to classify an input image between **3 animals - Cat, Dog and Panda**.
#
# ### <font style="color:green">What Do We Need and How to Achieve It? </font>
#
# You need correctly-labelled images of each animal. Train a decent-sized network to , understand the input image.

# %% [markdown]
# # <font style="color:blue">Step 2A: Get the Data </font><a name="step2a"></a>
#
# Let’s use a dataset from kaggle. [**Check it out here**](https://www.kaggle.com/ashishsaxena2209/animal-image-datasetdog-cat-and-panda).
#
# It has separate folders for each animal, each consisting of `1000` images. We have split it into `80:20` ratio for `train:validation`. To download, [**click  here**](https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1).

# %%
# !wget "https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1" -O data.zip

# %% [markdown]
# ### <font style="color:green">Extract the Data</font>

# %%
# !unzip -q data.zip

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # <font style="color:blue">Step 2B: Explore the Data [5 Points]</font><a name="step2b"></a>
#
# Here are  some examples:

# %% [markdown]
# ### <font style="color:green">Folder Structure </font>

# %%
# !tree -d ./cat-dog-panda
# Out:
# ./cat-dog-panda
# ├── training
# │   ├── cat
# │   ├── dog
# │   └── panda
# └── validation
#     ├── cat
#     ├── dog
#     └── panda
#
# 9 directories

# %% [markdown]
# ### <font style="color:green">Import the Datasets Module</font>
#
# Load the data,  using the datasets module, and . , check out its structure .

# %%
from torchvision import datasets

# %% [markdown]
# ### <font style="color:green">Create a Dataset Object </font>

# %%
train_data = datasets.ImageFolder("./cat-dog-panda/training")
validation_data = datasets.ImageFolder("./cat-dog-panda/validation")

# %% [markdown]
# ### <font style="color:green">List the Classes</font>
#
# It simply prints the sub folders present under the training or validation folder.

# %%
print(train_data.classes)
print(validation_data.classes)
# Out:
# ['cat', 'dog', 'panda']
# ['cat', 'dog', 'panda']

# %% [markdown]
# ### <font style="color:green">Get the Class ID to Name Mapping</font>

# %%
print(train_data.class_to_idx)
print(validation_data.class_to_idx)
# Out:
# {'cat': 0, 'dog': 1, 'panda': 2}
# {'cat': 0, 'dog': 1, 'panda': 2}

# %% [markdown]
# ### <font style="color:red">Find the Number of Samples in Training and Validation Folders [2 Points]</font>

# %%
# Import necessary libraries
import torch
from torchvision import datasets, transforms

# Set the path to the dataset
dataset_path = "./cat-dog-panda"

# # Define the data transforms
# transform = transforms.Compose([
#     transforms.Resize((224, 224)),
#     transforms.ToTensor(),
# ])

# Load the datasets
train_data = datasets.ImageFolder(root=f'{dataset_path}/training')
validation_data = datasets.ImageFolder(root=f'{dataset_path}/validation')
# # Load the datasets
# train_data = datasets.ImageFolder(root=f'{dataset_path}/training', transform=transform)
# validation_data = datasets.ImageFolder(root=f'{dataset_path}/validation', transform=transform)

# Display the number of samples in the training and validation folders
print(f"Number of samples in the training set: {len(train_data)}")
print(f"Number of samples in the validation set: {len(validation_data)}")
# Out:
# Number of samples in the training set: 2400
# Number of samples in the validation set: 600

# %% [markdown]
# ### <font style="color:red">Display Some Samples [3 Points]</font>
# Display one sample from each class. We know that the train dataset contains
#
# - cats from 0 to 799
# - dogs from 800 to 1599
# - pandas from 1600 to 2399
#
# Take one sample from each class and display using matplotlib

# %%
import torch
from torchvision import transforms, datasets
import matplotlib.pyplot as plt

# Assuming you have already loaded the training dataset
# and the data loader

# Set the path to the dataset
dataset_path = "./cat-dog-panda"

# Define the data transforms
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Load the training dataset
train_data = datasets.ImageFolder(root=f'{dataset_path}/training', transform=transform)

# Define a function to display an image
def show_sample(img, title):
    plt.imshow(img.permute(1, 2, 0))  # Convert (C, H, W) to (H, W, C)
    plt.title(title)
    plt.axis('off')
    plt.show()

# Display one sample from each class
class_indices = [0, 800, 1600]  # Indices corresponding to cat, dog, and panda in the training dataset
for idx in class_indices:
    img, label = train_data[idx]
    class_name = train_data.classes[label]
    show_sample(img, f"Class: {class_name}")


# print('image size: {}, target: {}'.format(img.size, target))

# plt.imshow(img)
# plt.show()

# %% [markdown]
# **Note:** The images are all of different size.

# %% [markdown]
# # <font style="color:blue">Step 2C: Create Sample Data</font><a name="step2c"></a>
#
# Take `5%` images from training and validation to create a small sample dataset, which will check our training pipeline.

# %%
import torch
import numpy as np

# %%
subset_size = .05

# %% [markdown]
# ### <font style="color:green">Create a Subset From the Original Data</font>
#
# Instead of copying the original data, use the `Subset` method in `Torch` to create a subset of the data. And use this to train the model.
#
#
# This is new. Let’ss see how it is done.

# %%
train_subset = torch.utils.data.Subset(train_data,np.arange(0,len(train_data),1./subset_size))
validation_subset = torch.utils.data.Subset(validation_data,np.arange(0,len(validation_data),1./subset_size))

# %%
train_subset_loader = torch.utils.data.DataLoader(train_subset,
                                         batch_size=8,
                                         num_workers=1,
                                         shuffle=False)
validation_subset_loader = torch.utils.data.DataLoader(validation_subset, 
                                         batch_size=8,
                                         num_workers=1,
                                         shuffle=False)

# %%
print("Train Subset Size: {}".format(len(train_subset_loader.dataset)))
print("Validation Subset Size: {}".format(len(validation_subset_loader.dataset)))
# Out:
# Train Subset Size: 120
# Validation Subset Size: 30

# %% [markdown]
# You can see that the subset data is only 5% of the original training and validation data.

# %% [markdown]
# We will create a separate function called `subset_data_loader` to create data loaders for subsets.

# %% [markdown]
# # <font style="color:blue">Step 3. Data Preparation [5 Points]</font>  <a name="step3"></a>
#
# Now that you have seen how the data is organized, configure the train and test loaders to feed  the training pipeline.

# %% [markdown]
# ## <font style="color:blue">3.1. Import Libraries </font>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms

from torch.optim import lr_scheduler

# %% [markdown]
# ## <font style="color:blue">3.2. Image Transforms</font>
#
# We need to normalize the data. Some of the  standard ways of doing it is to, subtract the mean, make all images equal in size or to rescale the range to \[0,1\] etc. , Use the following functions to do this:

# %% [markdown]
# ### <font style="color:green">3.2.1. Compulsary Preprocessing Transforms</font>

# %%
def image_preprocess_transforms():
    
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor()
        ])
    
    return preprocess

# %% [markdown]
# ### <font style="color:green">3.2.2. Common Image Transforms</font>
# Normalize for mean and std.
#
# You can add any other transforms here as per your dataset.

# %%
def image_common_transforms(mean=(0.4611, 0.4359, 0.3905), std=(0.2193, 0.2150, 0.2109)):
    preprocess = image_preprocess_transforms()
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %% [markdown]
# ### <font style="color:green">3.2.3. Mean and STD</font>
# Function for getting mean and variance

# %%
def get_mean_std(data_root, num_workers=4):
    
    transform = image_preprocess_transforms()
    
    loader = data_loader(data_root, transform)
    
    batch_mean = torch.zeros(3)
    batch_mean_sqrd = torch.zeros(3)
    
    for batch_data, _ in loader:
        batch_mean += batch_data.mean(dim=(0, 2, 3)) # E[batch_i] 
        batch_mean_sqrd += (batch_data ** 2).mean(dim=(0, 2, 3)) #  E[batch_i**2]
    
    # E[dataset] = E[E[batch_1], E[batch_2], ...]
    mean = batch_mean / len(loader)
    
    # var[X] = E[X**2] - E[X]**2
    
    # E[X**2] = E[E[batch_1**2], E[batch_2**2], ...]
    # E[X]**2 = E[E[batch_1], E[batch_2], ...] ** 2
    
    var = (batch_mean_sqrd / len(loader)) - (mean ** 2)
        
    std = var ** 0.5
    print('mean: {}, std: {}'.format(mean, std))
    
    return mean, std

# %% [markdown]
# ## <font style="color:blue">3.3. Data Loaders </font>

# %% [markdown]
# ### <font style="color:green">3.3.1. Data Loader for Full Data</font>
#
# Data loader used by the training routine to  generate batches of data:

# %%
def data_loader(data_root, transform, batch_size=16, shuffle=False, num_workers=2):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ### <font style="color:green">3.3.2. Data Loader for Subset</font>
# Data loader which uses the `subset` to generate batches

# %%
def subset_data_loader(data_root, transform, batch_size=8, shuffle=False, num_workers=2, subset_size=0.05):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    data_subset = torch.utils.data.Subset(dataset,np.arange(0,len(dataset),1./subset_size).astype(int))

    loader = torch.utils.data.DataLoader(data_subset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ## <font style="color:red">3.4. Prepare Data [5 Points]</font>
# The main function which uses all the above functions to generate the train and test dataloaders.

# %%
# Define a data_augmentation_preprocess function
def data_augmentation_preprocess(mean, std):
    # Add your data augmentation transformations here
    # Example: You can use torchvision transforms like RandomHorizontalFlip, RandomRotation, etc.
    augment_transforms = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        # Add more augmentations as needed
    ])
    
    preprocess = image_preprocess_transforms()
    
    # Combine data augmentation and preprocessing transforms
    transforms_combined = transforms.Compose([
        augment_transforms,
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return transforms_combined

# %%
def get_data(batch_size, data_root, num_workers=4, data_augmentation=False):
    
    train_data_path = os.path.join(data_root, 'training')
       
    mean, std = get_mean_std(data_root=train_data_path, num_workers=num_workers)
    
    common_transforms = image_common_transforms(mean, std)
        
   
    # if data_augmentation is true 
    # data augmentation implementation
    if data_augmentation:    
        train_transforms = data_augmentation_preprocess(mean, std)
    # else do common transforms
    else:
        train_transforms = common_transforms
        
        
    # train dataloader
    
    train_loader = subset_data_loader(train_data_path, 
                               train_transforms, 
                               batch_size=batch_size, 
                               shuffle=True, 
                               num_workers=num_workers)
    
    # test dataloader
    
    test_data_path = os.path.join(data_root, 'validation')
    
    test_transforms = image_preprocess_transforms()  # Use only preprocessing transforms
    
    test_loader = subset_data_loader(test_data_path, 
                              test_transforms, 
                              batch_size=batch_size, 
                              shuffle=False, 
                              num_workers=num_workers)
    
    return train_loader, test_loader

# %% [markdown]
# ### <font style="color:red">Question </font>[5 Points]
#
# There are two mistakes in the above code snippet.
# Spot the errors and correct them all.
# (Note: The rest of the code will run, even if you fail to find the mistakes.)
#
# The 2 mistakes that need to be fixed are:
# 1. One needs to define a data_augmentation_preprocess function.
# 2. The test_loader uses train_transforms.
# This is wrong.
# The validation/test set should not be subjected to any transformations apart from preprocessing transformations (resize, totensor, normalize, etc.)

# %% [markdown]
# # <font style="color:blue">Step 4: Train a Simple Model</font><a name="step4"></a>
#
# It is time to create the training pipeline and train a simple model on the sample data. We provide most of the code in this section. In the next notebook,  you  are the one who will have to make all the changes.

# %% [markdown]
# ## <font style="color:red">4.1. Configurations [ 5 Points]</font>
#
# In this section, define the training  and system configurations. Also, specify the batch size, data path, learning rate etc.
#
#
# ### <font style="color:red">Question </font>[5 Points]:
#
# Set up the training pipeline with a batch size of `4`. Run the experiment then for `100` epochs. Change the configurations as given below:

# %% [markdown]
# ### <font style="color:green">4.1.1. System Configuration</font>

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ### <font style="color:green">4.1.2. Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 4 #Set up the training pipeline with a batch size of `4`.
    epochs_count: int = 100 #Run the experiment then for `100` epochs.
    init_learning_rate: float = 0.0001  # initial learning rate for lr scheduler
    log_interval: int = 5  
    test_interval: int = 1  
    data_root: str = "./cat-dog-panda" 
    num_workers: int = 2  
    device: str = 'cuda'

# %% [markdown]
# ### <font style="color:green">4.1.3. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:blue">4.2. Training Function</font>
#
# You already know the training function. No need to make any changes:

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
):
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is medatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = F.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:blue">4.3. Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
):
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        with torch.no_grad():
            output = model(data)
        
        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device == 'cuda':
        model.to('cuda')
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.6. Main Function for Training</font>
#
# Please note here that before calling the train function, we calculate the validation loss.  It should be close to $log(\text{num_classes})$ and the accuracy should be close to  $\frac{1}{\text{num_classes}}$.

# %%
def main(model, optimizer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=True):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
        batch_size_to_set = 16
        num_workers_to_set = 4

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, 
                                                                                   init_val_accuracy*100))
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device)
        
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">4.8. Define Model</font>
#
# In the section,  define the CNN model and train the model.

# %%
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()

        # convolution layers
        self._body = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )

        
        # Fully connected layers
        self._head = nn.Sequential(
            nn.Linear(in_features=64*52*52, out_features=1024), 
            nn.ReLU(inplace=True),
            
            nn.Linear(in_features=1024, out_features=3)
            
        )
    
    def forward(self, x):
        
        # apply feature extractor
        x = self._body(x)
        # flatten the output of conv layers
        # dimension should be batch_size * number_of weight_in_last conv_layer
        x = x.view(x.size()[0], -1)
        # apply classification head
        x = self._head(x)
        
        
        return x

# %% [markdown]
# ## <font style="color:blue">4.9. Training</font>

# %%
model = MyModel()
print(model)

# get optimizer
train_config = TrainingConfiguration()

# optimizer
optimizer = optim.Adam(
    model.parameters(),
    lr = train_config.init_learning_rate
)
# Out:
# MyModel(
#   (_body): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=173056, out_features=1024, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=1024, out_features=3, bias=True)
#   )
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, optimizer, scheduler=None, data_augmentation=False)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])
#
# Test set: Average loss: 1.0994, Accuracy: 10/30 (33%)
#
# Initial Test Loss : 1.099368,
# Initial Test Accuracy : 33.333%
#
# Epoch: 0
# Train Loss: 1.865450 Acc: 0.4531
# Elapsed 7.89s, 7.89 s/epoch, 0.99 s/batch, ets 780.81s
#
# Test set: Average loss: 0.9997, Accuracy: 17/30 (57%)
#
# Model Improved. Saving the Model...
#
# Epoch: 1
# Train Loss: 0.794940 Acc: 0.6641
# Elapsed 27.83s, 13.91 s/epoch, 1.74 s/batch, ets 1363.65s
#
# Test set: Average loss: 1.5325, Accuracy: 10/30 (33%)
#
# Epoch: 2
# Train Loss: 0.606935 Acc: 0.7500
# Elapsed 46.96s, 15.65 s/epoch, 1.96 s/batch, ets 1518.39s
#
# Test set: Average loss: 1.1789, Accuracy: 11/30 (37%)
#
# Epoch: 3
# Train Loss: 0.361534 Acc: 0.8906
# Elapsed 66.04s, 16.51 s/epoch, 2.06 s/batch, ets 1584.85s
#
# Test set: Average loss: 1.4520, Accuracy: 10/30 (33%)
#
# Epoch: 4
# Train Loss: 0.198246 Acc: 0.9688
# Elapsed 85.22s, 17.04 s/epoch, 2.13 s/batch, ets 1619.21s
#
# Test set: Average loss: 1.4511, Accuracy: 10/30 (33%)
#
# Epoch: 5
# Train Loss: 0.104395 Acc: 0.9922
# Elapsed 104.45s, 17.41 s/epoch, 2.18 s/batch, ets 1636.42s
#
# Test set: Average loss: 1.7287, Accuracy: 10/30 (33%)
#
# Epoch: 6
# Train Loss: 0.041309 Acc: 1.0000
# Elapsed 123.49s, 17.64 s/epoch, 2.21 s/batch, ets 1640.69s
#
# Test set: Average loss: 1.6559, Accuracy: 10/30 (33%)
#
# Epoch: 7
# Train Loss: 0.020510 Acc: 1.0000
# Elapsed 143.04s, 17.88 s/epoch, 2.24 s/batch, ets 1644.98s
#
# Test set: Average loss: 1.7115, Accuracy: 10/30 (33%)
#
# Epoch: 8
# Train Loss: 0.010446 Acc: 1.0000
# Elapsed 162.41s, 18.05 s/epoch, 2.26 s/batch, ets 1642.12s
#
# Test set: Average loss: 1.9246, Accuracy: 10/30 (33%)
#
# Epoch: 9
# Train Loss: 0.005982 Acc: 1.0000
# Elapsed 181.94s, 18.19 s/epoch, 2.27 s/batch, ets 1637.46s
#
# Test set: Average loss: 2.0184, Accuracy: 10/30 (33%)
#
# Epoch: 10
# Train Loss: 0.004126 Acc: 1.0000
# Elapsed 201.43s, 18.31 s/epoch, 2.29 s/batch, ets 1629.72s
#
# Test set: Average loss: 2.0936, Accuracy: 10/30 (33%)
#
# Epoch: 11
# Train Loss: 0.003325 Acc: 1.0000
# Elapsed 220.93s, 18.41 s/epoch, 2.30 s/batch, ets 1620.13s
#
# Test set: Average loss: 2.1968, Accuracy: 10/30 (33%)
#
# Epoch: 12
# Train Loss: 0.002456 Acc: 1.0000
# Elapsed 240.28s, 18.48 s/epoch, 2.31 s/batch, ets 1608.05s
#
# Test set: Average loss: 2.2086, Accuracy: 10/30 (33%)
#
# Epoch: 13
# Train Loss: 0.002020 Acc: 1.0000
# Elapsed 259.77s, 18.56 s/epoch, 2.32 s/batch, ets 1595.76s
#
# Test set: Average loss: 2.2449, Accuracy: 10/30 (33%)
#
# Epoch: 14
# Train Loss: 0.001761 Acc: 1.0000
# Elapsed 279.00s, 18.60 s/epoch, 2.33 s/batch, ets 1581.01s
#
# Test set: Average loss: 2.2361, Accuracy: 10/30 (33%)
#
# Epoch: 15
# Train Loss: 0.001525 Acc: 1.0000
# Elapsed 298.21s, 18.64 s/epoch, 2.33 s/batch, ets 1565.59s
#
# Test set: Average loss: 2.2753, Accuracy: 10/30 (33%)
#
# Epoch: 16
# Train Loss: 0.001283 Acc: 1.0000
# Elapsed 317.39s, 18.67 s/epoch, 2.33 s/batch, ets 1549.60s
#
# Test set: Average loss: 2.3030, Accuracy: 10/30 (33%)
#
# Epoch: 17
# Train Loss: 0.001124 Acc: 1.0000
# Elapsed 336.58s, 18.70 s/epoch, 2.34 s/batch, ets 1533.31s
#
# Test set: Average loss: 2.3360, Accuracy: 10/30 (33%)
#
# Epoch: 18
# Train Loss: 0.001052 Acc: 1.0000
# Elapsed 355.68s, 18.72 s/epoch, 2.34 s/batch, ets 1516.31s
#
# Test set: Average loss: 2.3546, Accuracy: 10/30 (33%)
#
# Epoch: 19
# Train Loss: 0.000922 Acc: 1.0000
# Elapsed 375.23s, 18.76 s/epoch, 2.35 s/batch, ets 1500.94s
#
# Test set: Average loss: 2.3783, Accuracy: 10/30 (33%)
#
# Epoch: 20
# Train Loss: 0.000828 Acc: 1.0000
# Elapsed 394.52s, 18.79 s/epoch, 2.35 s/batch, ets 1484.15s
#
# Test set: Average loss: 2.4064, Accuracy: 10/30 (33%)
#
# Epoch: 21
# Train Loss: 0.000780 Acc: 1.0000
# Elapsed 413.85s, 18.81 s/epoch, 2.35 s/batch, ets 1467.30s
#
# Test set: Average loss: 2.4382, Accuracy: 10/30 (33%)
#
# Epoch: 22
# Train Loss: 0.000681 Acc: 1.0000
# Elapsed 433.36s, 18.84 s/epoch, 2.36 s/batch, ets 1450.80s
#
# Test set: Average loss: 2.4485, Accuracy: 10/30 (33%)
#
# Epoch: 23
# Train Loss: 0.000647 Acc: 1.0000
# Elapsed 452.60s, 18.86 s/epoch, 2.36 s/batch, ets 1433.23s
#
# Test set: Average loss: 2.4682, Accuracy: 10/30 (33%)
#
# Epoch: 24
# Train Loss: 0.000580 Acc: 1.0000
# Elapsed 471.88s, 18.88 s/epoch, 2.36 s/batch, ets 1415.63s
#
# Test set: Average loss: 2.4911, Accuracy: 10/30 (33%)
#
# Epoch: 25
# Train Loss: 0.000538 Acc: 1.0000
# Elapsed 490.97s, 18.88 s/epoch, 2.36 s/batch, ets 1397.38s
#
# Test set: Average loss: 2.5030, Accuracy: 10/30 (33%)
#
# Epoch: 26
# Train Loss: 0.000519 Acc: 1.0000
# Elapsed 510.02s, 18.89 s/epoch, 2.36 s/batch, ets 1378.95s
#
# Test set: Average loss: 2.5194, Accuracy: 10/30 (33%)
#
# Epoch: 27
# Train Loss: 0.000445 Acc: 1.0000
# Elapsed 529.11s, 18.90 s/epoch, 2.36 s/batch, ets 1360.57s
#
# Test set: Average loss: 2.5324, Accuracy: 10/30 (33%)
#
# Epoch: 28
# Train Loss: 0.000411 Acc: 1.0000
# Elapsed 548.35s, 18.91 s/epoch, 2.36 s/batch, ets 1342.52s
#
# Test set: Average loss: 2.5577, Accuracy: 10/30 (33%)
#
# Epoch: 29
# Train Loss: 0.000401 Acc: 1.0000
# Elapsed 567.78s, 18.93 s/epoch, 2.37 s/batch, ets 1324.81s
#
# Test set: Average loss: 2.5566, Accuracy: 10/30 (33%)
#
# Epoch: 30
# Train Loss: 0.000360 Acc: 1.0000
# Elapsed 587.07s, 18.94 s/epoch, 2.37 s/batch, ets 1306.71s
#
# Test set: Average loss: 2.5836, Accuracy: 10/30 (33%)
#
# Epoch: 31
# Train Loss: 0.000349 Acc: 1.0000
# Elapsed 606.31s, 18.95 s/epoch, 2.37 s/batch, ets 1288.40s
#
# Test set: Average loss: 2.6045, Accuracy: 10/30 (33%)
#
# Epoch: 32
# Train Loss: 0.000322 Acc: 1.0000
# Elapsed 625.50s, 18.95 s/epoch, 2.37 s/batch, ets 1269.95s
#
# Test set: Average loss: 2.6153, Accuracy: 10/30 (33%)
#
# Epoch: 33
# Train Loss: 0.000302 Acc: 1.0000
# Elapsed 644.74s, 18.96 s/epoch, 2.37 s/batch, ets 1251.55s
#
# Test set: Average loss: 2.6485, Accuracy: 10/30 (33%)
#
# Epoch: 34
# Train Loss: 0.000279 Acc: 1.0000
# Elapsed 664.04s, 18.97 s/epoch, 2.37 s/batch, ets 1233.22s
#
# Test set: Average loss: 2.6540, Accuracy: 10/30 (33%)
#
# Epoch: 35
# Train Loss: 0.000281 Acc: 1.0000
# Elapsed 683.62s, 18.99 s/epoch, 2.37 s/batch, ets 1215.32s
#
# Test set: Average loss: 2.6568, Accuracy: 10/30 (33%)
#
# Epoch: 36
# Train Loss: 0.000251 Acc: 1.0000
# Elapsed 703.00s, 19.00 s/epoch, 2.37 s/batch, ets 1196.99s
#
# Test set: Average loss: 2.6903, Accuracy: 10/30 (33%)
#
# Epoch: 37
# Train Loss: 0.000238 Acc: 1.0000
# Elapsed 722.48s, 19.01 s/epoch, 2.38 s/batch, ets 1178.78s
#
# Test set: Average loss: 2.6909, Accuracy: 10/30 (33%)
#
# Epoch: 38
# Train Loss: 0.000224 Acc: 1.0000
# Elapsed 741.75s, 19.02 s/epoch, 2.38 s/batch, ets 1160.18s
#
# Test set: Average loss: 2.7158, Accuracy: 10/30 (33%)
#
# Epoch: 39
# Train Loss: 0.000214 Acc: 1.0000
# Elapsed 760.96s, 19.02 s/epoch, 2.38 s/batch, ets 1141.45s
#
# Test set: Average loss: 2.7400, Accuracy: 10/30 (33%)
#
# Epoch: 40
# Train Loss: 0.000201 Acc: 1.0000
# Elapsed 780.15s, 19.03 s/epoch, 2.38 s/batch, ets 1122.66s
#
# Test set: Average loss: 2.7441, Accuracy: 10/30 (33%)
#
# Epoch: 41
# Train Loss: 0.000189 Acc: 1.0000
# Elapsed 799.21s, 19.03 s/epoch, 2.38 s/batch, ets 1103.67s
#
# Test set: Average loss: 2.7499, Accuracy: 10/30 (33%)
#
# Epoch: 42
# Train Loss: 0.000179 Acc: 1.0000
# Elapsed 818.70s, 19.04 s/epoch, 2.38 s/batch, ets 1085.25s
#
# Test set: Average loss: 2.7650, Accuracy: 10/30 (33%)
#
# Epoch: 43
# Train Loss: 0.000171 Acc: 1.0000
# Elapsed 838.09s, 19.05 s/epoch, 2.38 s/batch, ets 1066.66s
#
# Test set: Average loss: 2.7722, Accuracy: 10/30 (33%)
#
# Epoch: 44
# Train Loss: 0.000165 Acc: 1.0000
# Elapsed 857.43s, 19.05 s/epoch, 2.38 s/batch, ets 1047.97s
#
# Test set: Average loss: 2.7782, Accuracy: 10/30 (33%)
#
# Epoch: 45
# Train Loss: 0.000156 Acc: 1.0000
# Elapsed 876.55s, 19.06 s/epoch, 2.38 s/batch, ets 1029.00s
#
# Test set: Average loss: 2.7919, Accuracy: 10/30 (33%)
#
# Epoch: 46
# Train Loss: 0.000148 Acc: 1.0000
# Elapsed 895.79s, 19.06 s/epoch, 2.38 s/batch, ets 1010.15s
#
# Test set: Average loss: 2.8017, Accuracy: 10/30 (33%)
#
# Epoch: 47
# Train Loss: 0.000138 Acc: 1.0000
# Elapsed 914.94s, 19.06 s/epoch, 2.38 s/batch, ets 991.18s
#
# Test set: Average loss: 2.8245, Accuracy: 10/30 (33%)
#
# Epoch: 48
# Train Loss: 0.000137 Acc: 1.0000
# Elapsed 934.17s, 19.06 s/epoch, 2.38 s/batch, ets 972.30s
#
# Test set: Average loss: 2.8389, Accuracy: 10/30 (33%)
#
# Epoch: 49
# Train Loss: 0.000131 Acc: 1.0000
# Elapsed 953.40s, 19.07 s/epoch, 2.38 s/batch, ets 953.40s
#
# Test set: Average loss: 2.8444, Accuracy: 10/30 (33%)
#
# Epoch: 50
# Train Loss: 0.000129 Acc: 1.0000
# Elapsed 972.70s, 19.07 s/epoch, 2.38 s/batch, ets 934.55s
#
# Test set: Average loss: 2.8563, Accuracy: 10/30 (33%)
#
# Epoch: 51
# Train Loss: 0.000118 Acc: 1.0000
# Elapsed 991.83s, 19.07 s/epoch, 2.38 s/batch, ets 915.53s
#
# Test set: Average loss: 2.8534, Accuracy: 10/30 (33%)
#
# Epoch: 52
# Train Loss: 0.000111 Acc: 1.0000
# Elapsed 1010.94s, 19.07 s/epoch, 2.38 s/batch, ets 896.50s
#
# Test set: Average loss: 2.8633, Accuracy: 10/30 (33%)
#
# Epoch: 53
# Train Loss: 0.000108 Acc: 1.0000
# Elapsed 1030.27s, 19.08 s/epoch, 2.38 s/batch, ets 877.63s
#
# Test set: Average loss: 2.8686, Accuracy: 10/30 (33%)
#
# Epoch: 54
# Train Loss: 0.000107 Acc: 1.0000
# Elapsed 1049.53s, 19.08 s/epoch, 2.39 s/batch, ets 858.71s
#
# Test set: Average loss: 2.8879, Accuracy: 10/30 (33%)
#
# Epoch: 55
# Train Loss: 0.000104 Acc: 1.0000
# Elapsed 1068.94s, 19.09 s/epoch, 2.39 s/batch, ets 839.88s
#
# Test set: Average loss: 2.8894, Accuracy: 10/30 (33%)
#
# Epoch: 56
# Train Loss: 0.000100 Acc: 1.0000
# Elapsed 1088.29s, 19.09 s/epoch, 2.39 s/batch, ets 820.99s
#
# Test set: Average loss: 2.9068, Accuracy: 10/30 (33%)
#
# Epoch: 57
# Train Loss: 0.000095 Acc: 1.0000
# Elapsed 1107.47s, 19.09 s/epoch, 2.39 s/batch, ets 801.96s
#
# Test set: Average loss: 2.9067, Accuracy: 10/30 (33%)
#
# Epoch: 58
# Train Loss: 0.000090 Acc: 1.0000
# Elapsed 1126.76s, 19.10 s/epoch, 2.39 s/batch, ets 783.00s
#
# Test set: Average loss: 2.9083, Accuracy: 10/30 (33%)
#
# Epoch: 59
# Train Loss: 0.000087 Acc: 1.0000
# Elapsed 1145.91s, 19.10 s/epoch, 2.39 s/batch, ets 763.94s
#
# Test set: Average loss: 2.9175, Accuracy: 10/30 (33%)
#
# Epoch: 60
# Train Loss: 0.000081 Acc: 1.0000
# Elapsed 1165.36s, 19.10 s/epoch, 2.39 s/batch, ets 745.07s
#
# Test set: Average loss: 2.9264, Accuracy: 10/30 (33%)
#
# Epoch: 61
# Train Loss: 0.000078 Acc: 1.0000
# Elapsed 1184.78s, 19.11 s/epoch, 2.39 s/batch, ets 726.16s
#
# Test set: Average loss: 2.9244, Accuracy: 10/30 (33%)
#
# Epoch: 62
# Train Loss: 0.000076 Acc: 1.0000
# Elapsed 1204.00s, 19.11 s/epoch, 2.39 s/batch, ets 707.11s
#
# Test set: Average loss: 2.9443, Accuracy: 10/30 (33%)
#
# Epoch: 63
# Train Loss: 0.000074 Acc: 1.0000
# Elapsed 1223.13s, 19.11 s/epoch, 2.39 s/batch, ets 688.01s
#
# Test set: Average loss: 2.9501, Accuracy: 10/30 (33%)
#
# Epoch: 64
# Train Loss: 0.000073 Acc: 1.0000
# Elapsed 1242.43s, 19.11 s/epoch, 2.39 s/batch, ets 669.00s
#
# Test set: Average loss: 2.9647, Accuracy: 10/30 (33%)
#
# Epoch: 65
# Train Loss: 0.000069 Acc: 1.0000
# Elapsed 1261.80s, 19.12 s/epoch, 2.39 s/batch, ets 650.02s
#
# Test set: Average loss: 2.9687, Accuracy: 10/30 (33%)
#
# Epoch: 66
# Train Loss: 0.000067 Acc: 1.0000
# Elapsed 1281.18s, 19.12 s/epoch, 2.39 s/batch, ets 631.03s
#
# Test set: Average loss: 2.9782, Accuracy: 10/30 (33%)
#
# Epoch: 67
# Train Loss: 0.000064 Acc: 1.0000
# Elapsed 1300.24s, 19.12 s/epoch, 2.39 s/batch, ets 611.88s
#
# Test set: Average loss: 2.9835, Accuracy: 10/30 (33%)
#
# Epoch: 68
# Train Loss: 0.000061 Acc: 1.0000
# Elapsed 1319.25s, 19.12 s/epoch, 2.39 s/batch, ets 592.71s
#
# Test set: Average loss: 2.9936, Accuracy: 10/30 (33%)
#
# Epoch: 69
# Train Loss: 0.000061 Acc: 1.0000
# Elapsed 1338.43s, 19.12 s/epoch, 2.39 s/batch, ets 573.61s
#
# Test set: Average loss: 2.9984, Accuracy: 10/30 (33%)
#
# Epoch: 70
# Train Loss: 0.000058 Acc: 1.0000
# Elapsed 1357.53s, 19.12 s/epoch, 2.39 s/batch, ets 554.48s
#
# Test set: Average loss: 3.0103, Accuracy: 10/30 (33%)
#
# Epoch: 71
# Train Loss: 0.000058 Acc: 1.0000
# Elapsed 1376.69s, 19.12 s/epoch, 2.39 s/batch, ets 535.38s
#
# Test set: Average loss: 3.0212, Accuracy: 10/30 (33%)
#
# Epoch: 72
# Train Loss: 0.000054 Acc: 1.0000
# Elapsed 1395.80s, 19.12 s/epoch, 2.39 s/batch, ets 516.25s
#
# Test set: Average loss: 3.0259, Accuracy: 10/30 (33%)
#
# Epoch: 73
# Train Loss: 0.000054 Acc: 1.0000
# Elapsed 1415.06s, 19.12 s/epoch, 2.39 s/batch, ets 497.18s
#
# Test set: Average loss: 3.0311, Accuracy: 10/30 (33%)
#
# Epoch: 74
# Train Loss: 0.000051 Acc: 1.0000
# Elapsed 1434.57s, 19.13 s/epoch, 2.39 s/batch, ets 478.19s
#
# Test set: Average loss: 3.0432, Accuracy: 10/30 (33%)
#
# Epoch: 75
# Train Loss: 0.000051 Acc: 1.0000
# Elapsed 1453.68s, 19.13 s/epoch, 2.39 s/batch, ets 459.06s
#
# Test set: Average loss: 3.0466, Accuracy: 10/30 (33%)
#
# Epoch: 76
# Train Loss: 0.000047 Acc: 1.0000
# Elapsed 1472.95s, 19.13 s/epoch, 2.39 s/batch, ets 439.97s
#
# Test set: Average loss: 3.0574, Accuracy: 10/30 (33%)
#
# Epoch: 77
# Train Loss: 0.000047 Acc: 1.0000
# Elapsed 1492.17s, 19.13 s/epoch, 2.39 s/batch, ets 420.87s
#
# Test set: Average loss: 3.0671, Accuracy: 10/30 (33%)
#
# Epoch: 78
# Train Loss: 0.000046 Acc: 1.0000
# Elapsed 1511.51s, 19.13 s/epoch, 2.39 s/batch, ets 401.79s
#
# Test set: Average loss: 3.0660, Accuracy: 10/30 (33%)
#
# Epoch: 79
# Train Loss: 0.000043 Acc: 1.0000
# Elapsed 1530.69s, 19.13 s/epoch, 2.39 s/batch, ets 382.67s
#
# Test set: Average loss: 3.0756, Accuracy: 10/30 (33%)
#
# Epoch: 80
# Train Loss: 0.000043 Acc: 1.0000
# Elapsed 1549.98s, 19.14 s/epoch, 2.39 s/batch, ets 363.58s
#
# Test set: Average loss: 3.0850, Accuracy: 10/30 (33%)
#
# Epoch: 81
# Train Loss: 0.000041 Acc: 1.0000
# Elapsed 1569.23s, 19.14 s/epoch, 2.39 s/batch, ets 344.47s
#
# Test set: Average loss: 3.0909, Accuracy: 10/30 (33%)
#
# Epoch: 82
# Train Loss: 0.000043 Acc: 1.0000
# Elapsed 1588.35s, 19.14 s/epoch, 2.39 s/batch, ets 325.32s
#
# Test set: Average loss: 3.0960, Accuracy: 10/30 (33%)
#
# Epoch: 83
# Train Loss: 0.000039 Acc: 1.0000
# Elapsed 1607.69s, 19.14 s/epoch, 2.39 s/batch, ets 306.23s
#
# Test set: Average loss: 3.1008, Accuracy: 10/30 (33%)
#
# Epoch: 84
# Train Loss: 0.000039 Acc: 1.0000
# Elapsed 1626.95s, 19.14 s/epoch, 2.39 s/batch, ets 287.11s
#
# Test set: Average loss: 3.1154, Accuracy: 10/30 (33%)
#
# Epoch: 85
# Train Loss: 0.000038 Acc: 1.0000
# Elapsed 1646.20s, 19.14 s/epoch, 2.39 s/batch, ets 267.99s
#
# Test set: Average loss: 3.1192, Accuracy: 10/30 (33%)
#
# Epoch: 86
# Train Loss: 0.000035 Acc: 1.0000
# Elapsed 1665.43s, 19.14 s/epoch, 2.39 s/batch, ets 248.86s
#
# Test set: Average loss: 3.1204, Accuracy: 10/30 (33%)
#
# Epoch: 87
# Train Loss: 0.000035 Acc: 1.0000
# Elapsed 1684.88s, 19.15 s/epoch, 2.39 s/batch, ets 229.76s
#
# Test set: Average loss: 3.1214, Accuracy: 10/30 (33%)
#
# Epoch: 88
# Train Loss: 0.000034 Acc: 1.0000
# Elapsed 1704.37s, 19.15 s/epoch, 2.39 s/batch, ets 210.65s
#
# Test set: Average loss: 3.1305, Accuracy: 10/30 (33%)
#
# Epoch: 89
# Train Loss: 0.000033 Acc: 1.0000
# Elapsed 1723.63s, 19.15 s/epoch, 2.39 s/batch, ets 191.51s
#
# Test set: Average loss: 3.1382, Accuracy: 10/30 (33%)
#
# Epoch: 90
# Train Loss: 0.000034 Acc: 1.0000
# Elapsed 1742.92s, 19.15 s/epoch, 2.39 s/batch, ets 172.38s
#
# Test set: Average loss: 3.1393, Accuracy: 10/30 (33%)
#
# Epoch: 91
# Train Loss: 0.000031 Acc: 1.0000
# Elapsed 1762.10s, 19.15 s/epoch, 2.39 s/batch, ets 153.23s
#
# Test set: Average loss: 3.1481, Accuracy: 10/30 (33%)
#
# Epoch: 92
# Train Loss: 0.000031 Acc: 1.0000
# Elapsed 1781.33s, 19.15 s/epoch, 2.39 s/batch, ets 134.08s
#
# Test set: Average loss: 3.1583, Accuracy: 10/30 (33%)
#
# Epoch: 93
# Train Loss: 0.000029 Acc: 1.0000
# Elapsed 1800.36s, 19.15 s/epoch, 2.39 s/batch, ets 114.92s
#
# Test set: Average loss: 3.1625, Accuracy: 10/30 (33%)
#
# Epoch: 94
# Train Loss: 0.000030 Acc: 1.0000
# Elapsed 1819.42s, 19.15 s/epoch, 2.39 s/batch, ets 95.76s
#
# Test set: Average loss: 3.1659, Accuracy: 10/30 (33%)
#
# Epoch: 95
# Train Loss: 0.000029 Acc: 1.0000
# Elapsed 1838.57s, 19.15 s/epoch, 2.39 s/batch, ets 76.61s
#
# Test set: Average loss: 3.1730, Accuracy: 10/30 (33%)
#
# Epoch: 96
# Train Loss: 0.000028 Acc: 1.0000
# Elapsed 1857.65s, 19.15 s/epoch, 2.39 s/batch, ets 57.45s
#
# Test set: Average loss: 3.1702, Accuracy: 10/30 (33%)
#
# Epoch: 97
# Train Loss: 0.000028 Acc: 1.0000
# Elapsed 1876.95s, 19.15 s/epoch, 2.39 s/batch, ets 38.31s
#
# Test set: Average loss: 3.1838, Accuracy: 10/30 (33%)
#
# Epoch: 98
# Train Loss: 0.000027 Acc: 1.0000
# Elapsed 1896.21s, 19.15 s/epoch, 2.39 s/batch, ets 19.15s
#
# Test set: Average loss: 3.1901, Accuracy: 10/30 (33%)
#
# Epoch: 99
# Train Loss: 0.000026 Acc: 1.0000
# Elapsed 1915.72s, 19.16 s/epoch, 2.39 s/batch, ets 0.00s
#
# Test set: Average loss: 3.1972, Accuracy: 10/30 (33%)
#
# Total time: 1927.22, Best Loss: 1.000

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# # <font style="color:blue">Step 5: Sample Prediction</font><a name="predictions"></a>
#
# Show some sample predictions.

# %% [markdown]
# ## <font style="color:blue">5.1. Make Predictions</font>

# %%
def prediction(model, device, batch_input):
    
    data = batch_input.to(device)
    
    with torch.no_grad():
        output = model(data)

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the max probability
    pred_prob = prob.data.max(dim=1)[0]
    
    # get the index of the max probability
    pred_index = prob.data.max(dim=1)[1]
    
    return pred_index.cpu().numpy(), pred_prob.cpu().numpy()

# %% [markdown]
# ## <font style="color:blue">5.2. Get Predictions on a Batch</font>

# %%
def get_sample_prediction(model, data_root, mean, std):
    batch_size = 15

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
    
    # It is important to do model.eval() before prediction
    model.eval()
    
    # Send model to cpu/cuda according to your system configuration
    model.to(device)

    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    data_len = test_dataset.__len__()
    
    interval = int(data_len/batch_size)
    
    imgs = []
    inputs = []
    targets = []
    for i in range(batch_size):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        img, _ = test_dataset.__getitem__(index)
        
        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)
        
    inputs = torch.stack(inputs)
        
    cls, prob = prediction(model, device, batch_input=inputs)
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()
    
    
    for i, target in enumerate(targets):
        plt.subplot(3, 5, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[cls[i]], 
                                                     prob[i], 
                                                     test_dataset.classes[targets[i]]))
    fig.savefig('sample_prediction.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">5.3. Load Model and Run Inference</font>

# %%
m = MyModel()
m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')
train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)

get_sample_prediction(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])

# %% [markdown]
# Ddespite training the network on a very small subset of data, you can see that the predictions are not that bad. This means that our model is ready for training.

# %% [markdown]
# # <font style="color:red">Step 6. Display Mistakes [15 points] </font><a name="display"></a>
#
# The above code displayed sample predictions. But correct predictions are of no use. So, write a similar function that will  display only the mistakes made by the network.
#
#
# **You have to display only 15 images.**

# %%
def get_mistake_prediction(model, data_root, mean, std):
    batch_size = 15

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
    
    # It is important to do model.eval() before prediction
    model.eval()
    
    # Send model to cpu/cuda according to your system configuration
    model.to(device)

    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    data_len = test_dataset.__len__()
    
    interval = int(data_len / batch_size)
    
    imgs = []
    inputs = []
    targets = []
    mistakes = []

    for i in range(batch_size):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        img, _ = test_dataset.__getitem__(index)
        
        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)
        
    inputs = torch.stack(inputs)
        
    cls, prob = prediction(model, device, batch_input=inputs)
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()
    
    mistake_count = 0
    
    for i, target in enumerate(targets):
        if cls[i] != target:  # Check if the prediction is incorrect
            plt.subplot(3, 5, mistake_count + 1)
            img = transforms.functional.to_pil_image(imgs[i])
            plt.imshow(img)
            plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[cls[i]], 
                                                         prob[i], 
                                                         test_dataset.classes[targets[i]]))
            mistake_count += 1
            
        if mistake_count == 15:  # Display only 15 mistakes
            break

    fig.savefig('mistake_prediction.png')
    plt.show()

    return

# %%
# Load Model and Run Inference
m = MyModel()
m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')
train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)

get_mistake_prediction(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])

# %% [markdown]
# After completing the assignment, <font style="color:red">upload and submit the notebook on the portal</font> for checking and feedback.
